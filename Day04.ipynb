# %% [markdown]
# # List

# %%
container = ['name', 23, True, 50.3, None]
print(container)
print(type(container))
# Out:
# ['name', 23, True, 50.3, None]
# <class 'list'>

# %%
#Slicing
container
# Out:
# ['name', 23, True, 50.3, None]

# %%
container[0:1]
# Out:
# ['name']

# %%
container[0:3] #list [Start:Stop+1]
# Out:
# ['name', 23, True]

# %%
#Nested List
k = [1,2,3,4,5,[1,2,3,4,[1,2,3,4,'hello']]]

# %%
k[5][4][4]
# Out:
# 'hello'

# %%
k[-1][-1][-1]
# Out:
# 'hello'

# %%
len(k)
# Out:
# 6

# %%
k.append('new_item')

# %%
k
# Out:
# [1, 2, 3, 4, 5, [1, 2, 3, 4, [1, 2, 3, 4, 'hello']], 'new_item']

# %% [markdown]
# # tupple

# %%
t =(1,2,3,4,5)
print(type(t))
# Out:
# <class 'tuple'>

# %%
t
# Out:
# (1, 2, 3, 4, 5)

# %%
t.index(2)
# Out:
# 1

# %%
len(t)
# Out:
# 5

# %%
t[-1]
# Out:
# 5

# %% [markdown]
# # Set

# %%
u = [1,2,3,3,4,4,5,5,6,6,6,7]

# %%
set(u)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
name = list (set(u))

# %%
name
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# # Dictionary

# %%
d ={'key':'value'}

# %%
print(d['key'])
type(d)
# Out:
# value
# dict

# %%
visakh = {'name':'visakh', 
          'phone':'123456', 
          'address':{'home': 'Aus',
                     'office': 'city'}}

# %%
visakh.keys()
# Out:
# dict_keys(['name', 'phone', 'address'])

# %%
visakh.values()
# Out:
# dict_values(['visakh', '123456', {'home': 'Aus', 'office': 'city'}])

# %%
visakh['name']
# Out:
# 'visakh'

# %%
visakh['phone']
# Out:
# '123456'

# %%
car = {'brand':'toyota'}

# %%
car['brand']
# Out:
# 'toyota'

# %% [markdown]
# String Formatting

# %%
name = input('Enter you name')
print('Hello', name, 'your name contains', len(name), 'letters')
# Out:
# Hello vis your name contains 3 letters

# %%
print(f'Hello {name}, your name contains {len(name)} letters')
# Out:
# Hello vis, your name contains 3 letters
