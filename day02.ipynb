# %% [markdown]
# Day 02 Learning

# %%
print ("Day2")
# Out:
# Day2

# %%
#install library in notebook
#! used so that all updates are not displayed
# !pip install ipykernel
# !pip install numpy

# %% [markdown]
# # Data Types

# %%
name = 'bux' #string
print (name) #Print Variable doesn't need quotes
type (name)
# Out:
# bux
# str

# %%
age = 2.5
print (age)
type(age)
# Out:
# 2.5
# float

# %%
number_of_houses = 12 #variable should not have spaces
print(number_of_houses)
type(number_of_houses)
# Out:
# 12
# int

# %%
phone_number = 1234
type (phone_number)
#age =
# Out:
# int
