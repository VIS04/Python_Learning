# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.5-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# ...
#   Using cached numpy-2.5.1-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# ...
# Using cached pandas-3.0.5-cp314-cp314-macosx_11_0_arm64.whl (10.0 MB)
# Using cached numpy-2.5.1-cp314-cp314-macosx_14_0_arm64.whl (5.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('students.csv')

# %%
type (df)
# Out:
# pandas.DataFrame

# %%
df
# Out:
#     student_id          name age  gender                city  math_score  \
# 0            1    Arun Kumar  21    Male             Chennai          88
# 1            2    Priya Nair  22  Female               Kochi          95
# 2            3  Rahul Sharma  20    Male              Mumbai          72
# 3            4    Sneha Iyer  23  Female           Bangalore          60
# 4            5    Vikram Das  21    Male               Delhi          45
# 5            6  Meera Pillai  22  Female  Thiruvananthapuram          91
# 6            7   Arjun Menon  24    Male           Hyderabad          78
# 7            8   Divya Reddy      Female             Chennai          55
# 8            9   Kiran Patel  23    Male           Ahmedabad          82
# 9           10   Lakshmi Bai  21  Female               Kochi          98
# 10          11  Suresh Kumar  22    Male              Mumbai          30
# 11          12    Ananya Rao  20  Female           Bangalore          85
# ...

# %%
df.head()
# Out:
#    student_id          name age  gender       city  math_score  science_score  \
# 0           1    Arun Kumar  21    Male    Chennai          88             76
# 1           2    Priya Nair  22  Female      Kochi          95             89
# 2           3  Rahul Sharma  20    Male     Mumbai          72             65
# 3           4    Sneha Iyer  23  Female  Bangalore          60             55
# 4           5    Vikram Das  21    Male      Delhi          45             50
#
#    english_score grade  fees_paid
# 0             90     A       True
# 1             92    A+       True
# 2             80     B      False
# 3             70     C       True
# 4             60     D      False

# %%
df.tail()
# Out:
#     student_id          name age  gender                city  math_score  \
# 10          11  Suresh Kumar  22    Male              Mumbai          30
# 11          12    Ananya Rao  20  Female           Bangalore          85
# 12          13  Ravi Shankar  25    Male               Delhi          70
# 13          14   Pooja Menon  22  Female  Thiruvananthapuram          88
# 14          15  Ajith Thomas  21    Male               Kochi          62
#
#     science_score  english_score grade  fees_paid
# 10             40             50     F      False
# 11             80             78     A       True
# 12             68             75     B      False
# 13             91             89     A       True
# 14             58             72    C+       True

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   student_id     15 non-null     int64
#  1   name           15 non-null     str
#  2   age            15 non-null     str
#  3   gender         15 non-null     str
#  4   city           15 non-null     str
#  5   math_score     15 non-null     int64
#  6   science_score  15 non-null     int64
#  7   english_score  15 non-null     int64
#  8   grade          15 non-null     str
#  9   fees_paid      15 non-null     bool
# dtypes: bool(1), int64(4), str(5)
# memory usage: 1.2 KB

# %%
df.describe()
# Out:
#        student_id  math_score  science_score  english_score
# count   15.000000   15.000000      15.000000      15.000000
# mean     8.000000   73.266667      71.733333      77.666667
# std      4.472136   19.619475      16.615254      13.025616
# min      1.000000   30.000000      40.000000      50.000000
# 25%      4.500000   61.000000      59.000000      71.000000
# 50%      8.000000   78.000000      76.000000      78.000000
# 75%     11.500000   88.000000      85.000000      88.500000
# max     15.000000   98.000000      95.000000      97.000000

# %%
df.shape #(rows,column)
# Out:
# (15, 10)

# %%
df.shape[0]
# Out:
# 15

# %%
df.shape[1]
# Out:
# 10

# %%
print(f'The dataframe has {df.shape[0]} rows')
# Out:
# The dataframe has 15 rows

# %%
df.columns
# Out:
# Index(['student_id', 'name', 'age', 'gender', 'city', 'math_score',
#        'science_score', 'english_score', 'grade', 'fees_paid'],
#       dtype='str')

# %%
df.name #as series
# Out:
# 0       Arun Kumar
# 1       Priya Nair
# 2     Rahul Sharma
# 3       Sneha Iyer
# 4       Vikram Das
# 5     Meera Pillai
# 6      Arjun Menon
# 7      Divya Reddy
# 8      Kiran Patel
# 9      Lakshmi Bai
# 10    Suresh Kumar
# 11      Ananya Rao
# 12    Ravi Shankar
# 13     Pooja Menon
# 14    Ajith Thomas
# Name: name, dtype: str

# %%
df['name'] #as series
# Out:
# 0       Arun Kumar
# 1       Priya Nair
# 2     Rahul Sharma
# 3       Sneha Iyer
# 4       Vikram Das
# 5     Meera Pillai
# 6      Arjun Menon
# 7      Divya Reddy
# 8      Kiran Patel
# 9      Lakshmi Bai
# 10    Suresh Kumar
# 11      Ananya Rao
# 12    Ravi Shankar
# 13     Pooja Menon
# 14    Ajith Thomas
# Name: name, dtype: str

# %%
df[['name']] #as dataframe
# Out:
#             name
# 0     Arun Kumar
# 1     Priya Nair
# 2   Rahul Sharma
# 3     Sneha Iyer
# 4     Vikram Das
# 5   Meera Pillai
# 6    Arjun Menon
# 7    Divya Reddy
# 8    Kiran Patel
# 9    Lakshmi Bai
# 10  Suresh Kumar
# 11    Ananya Rao
# 12  Ravi Shankar
# 13   Pooja Menon
# 14  Ajith Thomas

# %%
s = df['name'] #series
s.shape # only 1 dimension
# Out:
# (15,)

# %%
d = df[['name']] #dataframe
d.shape # 2 dimensions
# Out:
# (15, 1)

# %%
df.head()
# Out:
#    student_id          name age  gender       city  math_score  science_score  \
# 0           1    Arun Kumar  21    Male    Chennai          88             76
# 1           2    Priya Nair  22  Female      Kochi          95             89
# 2           3  Rahul Sharma  20    Male     Mumbai          72             65
# 3           4    Sneha Iyer  23  Female  Bangalore          60             55
# 4           5    Vikram Das  21    Male      Delhi          45             50
#
#    english_score grade  fees_paid
# 0             90     A       True
# 1             92    A+       True
# 2             80     B      False
# 3             70     C       True
# 4             60     D      False

# %%
df.columns
# Out:
# Index(['student_id', 'name', 'age', 'gender', 'city', 'math_score',
#        'science_score', 'english_score', 'grade', 'fees_paid'],
#       dtype='str')

# %%
subdf = df[['name', 'age', 'gender']]

# %%
subdf
# Out:
#             name age  gender
# 0     Arun Kumar  21    Male
# 1     Priya Nair  22  Female
# 2   Rahul Sharma  20    Male
# 3     Sneha Iyer  23  Female
# 4     Vikram Das  21    Male
# 5   Meera Pillai  22  Female
# 6    Arjun Menon  24    Male
# 7    Divya Reddy      Female
# 8    Kiran Patel  23    Male
# 9    Lakshmi Bai  21  Female
# 10  Suresh Kumar  22    Male
# 11    Ananya Rao  20  Female
# 12  Ravi Shankar  25    Male
# 13   Pooja Menon  22  Female
# 14  Ajith Thomas  21    Male

# %%
df.city.unique()
# Out:
# <StringArray>
# [           'Chennai',              'Kochi',             'Mumbai',
#           'Bangalore',              'Delhi', 'Thiruvananthapuram',
#           'Hyderabad',          'Ahmedabad']
# Length: 8, dtype: str

# %%
df.city.nunique()
# Out:
# 8

# %%
df['city'].value_counts()
# Out:
# city
# Kochi                 3
# Chennai               2
# Mumbai                2
# Bangalore             2
# Delhi                 2
# Thiruvananthapuram    2
# Hyderabad             1
# Ahmedabad             1
# Name: count, dtype: int64
