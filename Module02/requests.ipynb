# %% [markdown]
# #  Requests

# %%
import requests
import json

# %%
student ={
    "name":"saravana",
    "class":"AI"
}

# %%
json_string= json.dumps(student) #dictionay to a Json string

# %%
json_string
# Out:
# '{"name": "saravana", "class": "AI"}'

# %%
type(json_string)
# Out:
# str

# %%
parsed_back = json.loads(json_string)
parsed_back
# Out:
# {'name': 'saravana', 'class': 'AI'}

# %%
type(parsed_back)
# Out:
# dict

# %%
import requests
url = "https://jsonplaceholder.typicode.com/posts/1"
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.headers.get("content-type")
# Out:
# 'application/json; charset=utf-8'

# %%
print(response.text)
# Out:
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }

# %%
print(response.text[0:50])
# Out:
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut f

# %%
import requests
url = "https://jsonplaceholder.typicode.com/posts"
response = requests.get(url,params = {"userId":1})
response.json()
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %%
len(response.json())
# Out:
# 10

# %%
response.url
# Out:
# 'https://jsonplaceholder.typicode.com/posts?userId=1'

# %%
selection = response.json()

# %%
type(selection)
# Out:
# list

# %%
new_post={"title": "Learning APIs in Kochi",
    "body": "Day 2 of the workshop covers requests, REST and JSON.",
    "userId": 101}

# %%
response = requests.post(url, json=new_post)

# %%
response.status_code
# Out:
# 201

# %%
response.json()
# Out:
# {'title': 'Learning APIs in Kochi',
#  'body': 'Day 2 of the workshop covers requests, REST and JSON.',
#  'userId': 101,
#  'id': 101}

# %%
response.url
# Out:
# 'https://jsonplaceholder.typicode.com/posts'

# %%
api="e7f1817be97143e6a7a06f80247bbe4c"
url="https://api.openweathermap.org/data/4.0/onecall/current?lat=52.2297&lon=21.0122&units=metric&lang=en&appid={e7f1817be97143e6a7a06f80247bbe4c} "

# %%
requests.get(url)
# Out:
# <Response [401]>
